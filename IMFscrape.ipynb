# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import pandas as pd
import os
import time
from concurrent.futures import ThreadPoolExecutor, as_completed

# Setup Chrome options
chrome_options = Options()
chrome_options.add_argument("--headless")
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--window-size=1920x1080")
chrome_options.add_argument("--log-level=3")
chrome_options.add_argument("--start-maximized")
chrome_options.add_argument('--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36')
chrome_options.add_experimental_option("excludeSwitches", ["enable-logging"])

# Path to ChromeDriver
chromedriver_path = r"C:\Users\yujit\OneDrive\Desktop\chromedriver-win64\chromedriver.exe"

# Create output folder
output_folder = "IMF"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Base URL of IMF eLibrary
base_url = "https://www.elibrary.imf.org/browse?page="

# Function to initialize WebDriver
def init_driver():
    service = Service(chromedriver_path)
    return webdriver.Chrome(service=service, options=chrome_options)

# Function to scrape a page
def scrape_page(page_num):
    driver = init_driver()
    driver.get(f"{base_url}{page_num}&pageSize=50&sort=datedescending")
    time.sleep(5)  # Allow page to load

    local_data = []
    articles = driver.find_elements(By.CLASS_NAME, "typography-body.text-title.fw-4")

    for article in articles:
        try:
            title_element = article.find_element(By.TAG_NAME, "a")
            title = title_element.text.strip()
        except:
            title = "N/A"

        def extract_data(xpath):
            try:
                return driver.find_element(By.XPATH, xpath).text.strip()
            except:
                return "N/A"

        # Extracting metadata using provided XPaths
        data = {
            "Title": title,
            "Type": extract_data("//dl[@class='type c-List__items']/dd/span"),
            "Source Title": extract_data("//dl[@class='sourcetitle c-List__items']/dd/span"),
            "Volume": extract_data("//dl[@class='volumeissue c-List__items']/dd/span/a") or extract_data("//dl[@class='volumeissue c-List__items']/dd/span"),
            "Series": extract_data("//dl[@class='editorialType c-List__items']/dd/span"),
            "Publisher": extract_data("//dl[@class='publisher c-List__items']/dd/span"),
            "Publication Date": extract_data("//dl[@class='printpubdate c-List__items']/dd/span"),
            "Language": extract_data("//dl[@class='language c-List__items']/dd/span"),
            "DOI": extract_data("//dl[@class='doi c-List__items']/dd/span/a"),
            "ISBN": extract_data("//dl[@class='formatisbn c-List__items']/dd/span"),
        }

        local_data.append(data)

    driver.quit()

    # Save data to a separate file for each page
    df = pd.DataFrame(local_data)
    output_file = os.path.join(output_folder, f"IMF_Page_{page_num}.xlsx")
    df.to_excel(output_file, index=False)
    print(f"Page {page_num} scraped and saved as {output_file}")

    return local_data

# Multi-threaded scraping
page_number = 1  # Start page
max_workers = 2  # Number of pages to scrape in parallel
pages_scraped = 0

with ThreadPoolExecutor(max_workers=max_workers) as executor:
    while True:
        futures = {executor.submit(scrape_page, page_num): page_num for page_num in range(page_number, page_number + max_workers)}

        all_results = []
        for future in as_completed(futures):
            result = future.result()
            if not result:
                print(f"No more data found on page {futures[future]}. Stopping scraping.")
                break
            all_results.extend(result)
            pages_scraped += 1

        page_number += max_workers

        # Pause for 2 minutes after every 12 pages scraped
        if pages_scraped >= 12:
            print("Pausing for 2 minutes to avoid detection...")
            time.sleep(120)
            pages_scraped = 0  # Reset counter

        if len(all_results) == 0:
            break

print("Scraping complete.")
# Out:
# Page 1987 scraped and saved as IMF\IMF_Page_1987.xlsxPage 1986 scraped and saved as IMF\IMF_Page_1986.xlsx
#
# Page 1988 scraped and saved as IMF\IMF_Page_1988.xlsx
# Page 1989 scraped and saved as IMF\IMF_Page_1989.xlsx
# Page 1991 scraped and saved as IMF\IMF_Page_1991.xlsx
# Page 1990 scraped and saved as IMF\IMF_Page_1990.xlsx
# Page 1992 scraped and saved as IMF\IMF_Page_1992.xlsx
# Page 1993 scraped and saved as IMF\IMF_Page_1993.xlsx
# Page 1994 scraped and saved as IMF\IMF_Page_1994.xlsx
# Page 1995 scraped and saved as IMF\IMF_Page_1995.xlsx
# Page 1997 scraped and saved as IMF\IMF_Page_1997.xlsx
# Page 1996 scraped and saved as IMF\IMF_Page_1996.xlsx
# Pausing for 2 minutes to avoid detection...
# Page 1998 scraped and saved as IMF\IMF_Page_1998.xlsx
# Page 1999 scraped and saved as IMF\IMF_Page_1999.xlsx
# Page 2000 scraped and saved as IMF\IMF_Page_2000.xlsx
# Page 2001 scraped and saved as IMF\IMF_Page_2001.xlsx
# Page 2002 scraped and saved as IMF\IMF_Page_2002.xlsx
# Page 2003 scraped and saved as IMF\IMF_Page_2003.xlsx
# Page 2004 scraped and saved as IMF\IMF_Page_2004.xlsx
# Page 2005 scraped and saved as IMF\IMF_Page_2005.xlsx
# Page 2006 scraped and saved as IMF\IMF_Page_2006.xlsx
# Page 2007 scraped and saved as IMF\IMF_Page_2007.xlsx
# Page 2008 scraped and saved as IMF\IMF_Page_2008.xlsx
# Page 2009 scraped and saved as IMF\IMF_Page_2009.xlsx
# Pausing for 2 minutes to avoid detection...
# Page 2010 scraped and saved as IMF\IMF_Page_2010.xlsx
# Page 2011 scraped and saved as IMF\IMF_Page_2011.xlsx
# Page 2013 scraped and saved as IMF\IMF_Page_2013.xlsx
# Page 2012 scraped and saved as IMF\IMF_Page_2012.xlsx
# Page 2014 scraped and saved as IMF\IMF_Page_2014.xlsx
# Page 2015 scraped and saved as IMF\IMF_Page_2015.xlsx
# Page 2017 scraped and saved as IMF\IMF_Page_2017.xlsx
# Page 2016 scraped and saved as IMF\IMF_Page_2016.xlsx
# Page 2018 scraped and saved as IMF\IMF_Page_2018.xlsx
# Page 2019 scraped and saved as IMF\IMF_Page_2019.xlsx
# Page 2021 scraped and saved as IMF\IMF_Page_2021.xlsx
# Page 2020 scraped and saved as IMF\IMF_Page_2020.xlsx
# Pausing for 2 minutes to avoid detection...
# Page 2023 scraped and saved as IMF\IMF_Page_2023.xlsx
# Page 2022 scraped and saved as IMF\IMF_Page_2022.xlsx
# Page 2024 scraped and saved as IMF\IMF_Page_2024.xlsx
# Page 2025 scraped and saved as IMF\IMF_Page_2025.xlsx
# Page 2027 scraped and saved as IMF\IMF_Page_2027.xlsx
# Page 2026 scraped and saved as IMF\IMF_Page_2026.xlsx
# Page 2029 scraped and saved as IMF\IMF_Page_2029.xlsx
# Page 2028 scraped and saved as IMF\IMF_Page_2028.xlsx
# Page 2031 scraped and saved as IMF\IMF_Page_2031.xlsx
# Page 2030 scraped and saved as IMF\IMF_Page_2030.xlsx
# Page 2032 scraped and saved as IMF\IMF_Page_2032.xlsx
# Page 2033 scraped and saved as IMF\IMF_Page_2033.xlsx
# Pausing for 2 minutes to avoid detection...
# Page 2034 scraped and saved as IMF\IMF_Page_2034.xlsx
# Page 2035 scraped and saved as IMF\IMF_Page_2035.xlsx
# Page 2037 scraped and saved as IMF\IMF_Page_2037.xlsx
# Page 2036 scraped and saved as IMF\IMF_Page_2036.xlsx
# Page 2039 scraped and saved as IMF\IMF_Page_2039.xlsx
# Page 2038 scraped and saved as IMF\IMF_Page_2038.xlsx
# Page 2040 scraped and saved as IMF\IMF_Page_2040.xlsx
# Page 2041 scraped and saved as IMF\IMF_Page_2041.xlsx
# Page 2042 scraped and saved as IMF\IMF_Page_2042.xlsx
# Page 2043 scraped and saved as IMF\IMF_Page_2043.xlsx
# Page 2044 scraped and saved as IMF\IMF_Page_2044.xlsx
# Page 2045 scraped and saved as IMF\IMF_Page_2045.xlsx
# Pausing for 2 minutes to avoid detection...
# Page 2046 scraped and saved as IMF\IMF_Page_2046.xlsx
# Page 2047 scraped and saved as IMF\IMF_Page_2047.xlsx
# Page 2049 scraped and saved as IMF\IMF_Page_2049.xlsx
# Page 2048 scraped and saved as IMF\IMF_Page_2048.xlsx
# Page 2050 scraped and saved as IMF\IMF_Page_2050.xlsx
# Page 2051 scraped and saved as IMF\IMF_Page_2051.xlsx
# Page 2052 scraped and saved as IMF\IMF_Page_2052.xlsx
# Page 2053 scraped and saved as IMF\IMF_Page_2053.xlsx
# Page 2054 scraped and saved as IMF\IMF_Page_2054.xlsx
# Page 2055 scraped and saved as IMF\IMF_Page_2055.xlsx
# Page 2057 scraped and saved as IMF\IMF_Page_2057.xlsx
# Page 2056 scraped and saved as IMF\IMF_Page_2056.xlsx
# Pausing for 2 minutes to avoid detection...
# Page 2058 scraped and saved as IMF\IMF_Page_2058.xlsx
# Page 2059 scraped and saved as IMF\IMF_Page_2059.xlsx
# Page 2060 scraped and saved as IMF\IMF_Page_2060.xlsx
# Page 2061 scraped and saved as IMF\IMF_Page_2061.xlsx
# Page 2063 scraped and saved as IMF\IMF_Page_2063.xlsx
# Page 2062 scraped and saved as IMF\IMF_Page_2062.xlsx
# Page 2064 scraped and saved as IMF\IMF_Page_2064.xlsx
# Page 2065 scraped and saved as IMF\IMF_Page_2065.xlsx
# Page 2067 scraped and saved as IMF\IMF_Page_2067.xlsx
# Page 2066 scraped and saved as IMF\IMF_Page_2066.xlsx
# Page 2069 scraped and saved as IMF\IMF_Page_2069.xlsx
# Page 2068 scraped and saved as IMF\IMF_Page_2068.xlsx
# Pausing for 2 minutes to avoid detection...
# Page 2071 scraped and saved as IMF\IMF_Page_2071.xlsx
# Page 2070 scraped and saved as IMF\IMF_Page_2070.xlsx
# Page 2072 scraped and saved as IMF\IMF_Page_2072.xlsx
# Page 2073 scraped and saved as IMF\IMF_Page_2073.xlsx
# Page 2074 scraped and saved as IMF\IMF_Page_2074.xlsx
# Page 2075 scraped and saved as IMF\IMF_Page_2075.xlsx
# Page 2077 scraped and saved as IMF\IMF_Page_2077.xlsx
# Page 2076 scraped and saved as IMF\IMF_Page_2076.xlsx
# Page 2078 scraped and saved as IMF\IMF_Page_2078.xlsx
# Page 2079 scraped and saved as IMF\IMF_Page_2079.xlsx
# Page 2080 scraped and saved as IMF\IMF_Page_2080.xlsx
# Page 2081 scraped and saved as IMF\IMF_Page_2081.xlsx
# Pausing for 2 minutes to avoid detection...
# Page 2082 scraped and saved as IMF\IMF_Page_2082.xlsx
# Page 2083 scraped and saved as IMF\IMF_Page_2083.xlsx
# Page 2084 scraped and saved as IMF\IMF_Page_2084.xlsx
# Page 2085 scraped and saved as IMF\IMF_Page_2085.xlsx
# Page 2086 scraped and saved as IMF\IMF_Page_2086.xlsx
# Page 2087 scraped and saved as IMF\IMF_Page_2087.xlsx
# Page 2088 scraped and saved as IMF\IMF_Page_2088.xlsx
# Page 2089 scraped and saved as IMF\IMF_Page_2089.xlsx
# Page 2090 scraped and saved as IMF\IMF_Page_2090.xlsx
# Page 2091 scraped and saved as IMF\IMF_Page_2091.xlsx
# Page 2093 scraped and saved as IMF\IMF_Page_2093.xlsx
# Page 2092 scraped and saved as IMF\IMF_Page_2092.xlsx
# Pausing for 2 minutes to avoid detection...
# Page 2094 scraped and saved as IMF\IMF_Page_2094.xlsx
# Page 2095 scraped and saved as IMF\IMF_Page_2095.xlsx
# Page 2096 scraped and saved as IMF\IMF_Page_2096.xlsx
# Page 2097 scraped and saved as IMF\IMF_Page_2097.xlsx
# Page 2099 scraped and saved as IMF\IMF_Page_2099.xlsx
# Page 2098 scraped and saved as IMF\IMF_Page_2098.xlsx
# Page 2100 scraped and saved as IMF\IMF_Page_2100.xlsx
# Page 2101 scraped and saved as IMF\IMF_Page_2101.xlsx
# Page 2103 scraped and saved as IMF\IMF_Page_2103.xlsx
# Page 2102 scraped and saved as IMF\IMF_Page_2102.xlsx
# Page 2105 scraped and saved as IMF\IMF_Page_2105.xlsx
# Page 2104 scraped and saved as IMF\IMF_Page_2104.xlsx
# Pausing for 2 minutes to avoid detection...
# Page 2106 scraped and saved as IMF\IMF_Page_2106.xlsx
# Page 2107 scraped and saved as IMF\IMF_Page_2107.xlsx
# Page 2109 scraped and saved as IMF\IMF_Page_2109.xlsx
# Page 2108 scraped and saved as IMF\IMF_Page_2108.xlsx
# Page 2110 scraped and saved as IMF\IMF_Page_2110.xlsx
# Page 2111 scraped and saved as IMF\IMF_Page_2111.xlsx
# Page 2112 scraped and saved as IMF\IMF_Page_2112.xlsx
# Page 2113 scraped and saved as IMF\IMF_Page_2113.xlsx
# Page 2114 scraped and saved as IMF\IMF_Page_2114.xlsx
# Page 2115 scraped and saved as IMF\IMF_Page_2115.xlsx
# Page 2116 scraped and saved as IMF\IMF_Page_2116.xlsx
# Page 2117 scraped and saved as IMF\IMF_Page_2117.xlsx
# Pausing for 2 minutes to avoid detection...
# Page 2119 scraped and saved as IMF\IMF_Page_2119.xlsx
# Page 2118 scraped and saved as IMF\IMF_Page_2118.xlsx
# Page 2121 scraped and saved as IMF\IMF_Page_2121.xlsx
# Page 2120 scraped and saved as IMF\IMF_Page_2120.xlsx
# Page 2123 scraped and saved as IMF\IMF_Page_2123.xlsx
# Page 2122 scraped and saved as IMF\IMF_Page_2122.xlsx
# Page 2125 scraped and saved as IMF\IMF_Page_2125.xlsx
# Page 2124 scraped and saved as IMF\IMF_Page_2124.xlsx
# Page 2126 scraped and saved as IMF\IMF_Page_2126.xlsx
# Page 2127 scraped and saved as IMF\IMF_Page_2127.xlsx
# Page 2129 scraped and saved as IMF\IMF_Page_2129.xlsx
# Page 2128 scraped and saved as IMF\IMF_Page_2128.xlsx
# Pausing for 2 minutes to avoid detection...
# Page 2131 scraped and saved as IMF\IMF_Page_2131.xlsx
# Page 2130 scraped and saved as IMF\IMF_Page_2130.xlsx
# Page 2132 scraped and saved as IMF\IMF_Page_2132.xlsx
# Page 2133 scraped and saved as IMF\IMF_Page_2133.xlsx
# Page 2135 scraped and saved as IMF\IMF_Page_2135.xlsx
# Page 2134 scraped and saved as IMF\IMF_Page_2134.xlsx
# Page 2136 scraped and saved as IMF\IMF_Page_2136.xlsx
# Page 2137 scraped and saved as IMF\IMF_Page_2137.xlsx
# Page 2139 scraped and saved as IMF\IMF_Page_2139.xlsx
# Page 2138 scraped and saved as IMF\IMF_Page_2138.xlsx
# Page 2141 scraped and saved as IMF\IMF_Page_2141.xlsx
# Page 2140 scraped and saved as IMF\IMF_Page_2140.xlsx
# Pausing for 2 minutes to avoid detection...
# Page 2142 scraped and saved as IMF\IMF_Page_2142.xlsx
# Page 2143 scraped and saved as IMF\IMF_Page_2143.xlsx
# Page 2144 scraped and saved as IMF\IMF_Page_2144.xlsx
# Page 2145 scraped and saved as IMF\IMF_Page_2145.xlsx
# Page 2146 scraped and saved as IMF\IMF_Page_2146.xlsx
# Page 2147 scraped and saved as IMF\IMF_Page_2147.xlsx
# Page 2148 scraped and saved as IMF\IMF_Page_2148.xlsx
# Page 2149 scraped and saved as IMF\IMF_Page_2149.xlsx
# Page 2150 scraped and saved as IMF\IMF_Page_2150.xlsx
# Page 2151 scraped and saved as IMF\IMF_Page_2151.xlsx
# Page 2152 scraped and saved as IMF\IMF_Page_2152.xlsx
# Page 2153 scraped and saved as IMF\IMF_Page_2153.xlsx
# Pausing for 2 minutes to avoid detection...
# Page 2154 scraped and saved as IMF\IMF_Page_2154.xlsx
# Page 2155 scraped and saved as IMF\IMF_Page_2155.xlsx
# Page 2157 scraped and saved as IMF\IMF_Page_2157.xlsx
# No more data found on page 2157. Stopping scraping.
# Page 2156 scraped and saved as IMF\IMF_Page_2156.xlsx
# Scraping complete.
